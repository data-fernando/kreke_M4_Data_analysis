# %%
import pandas as pd

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
url = "ventas_limpias.csv"
df = pd.read_csv(url, header=0)
print(df.head())
# Out:
#   ID_venta    Sucursal       Fecha  ID_producto Nombre_producto  \
# 0    V1000  Sucursal 1  2023-03-16            7           Reloj
# 1    V1001  Sucursal 1  2023-01-12            7           Reloj
# 2    V1002  Sucursal 1  2023-03-23            8          Tablet
# 3    V1003  Sucursal 1  2023-03-02           10       Bicicleta
# 4    V1004  Sucursal 1  2023-03-05           10       Bicicleta
#
#   Categoría_producto  Precio_unitario  Cantidad_vendida  Monto_total  \
# 0         Accesorios            150.0                 4        510.0
# 1         Accesorios            150.0                 2        240.0
# 2        Electronica            300.0                 4       1140.0
# 3         Accesorios            400.0                 8       2880.0
# 4         Accesorios            400.0                 4       1280.0
#
#   ID_empleado Nombre_empleado  Evaluación_atención  Descuento  \
# 0          E1    Carlos Perez                    2         15
# ...
